# %%
import pandas as pd
import math

# %%
df = pd.read_csv('drugs.csv')

# %%
df_clean = pd.DataFrame()
to_start = 0
cell = 0
row = df.shape[0]
col = df.shape[1]

my_type = type('omar')

for i in range(row):
    cell = 0
    for j in range(col):
        if type(df.iloc[i,j]) == my_type:
            df_clean.at[i,cell] = df.iloc[i,j]
            cell += 1

# %%
df_clean.to_csv('final.csv')

# %%
pd.read_csv('final.csv')
# Out:
# C:\Users\omarr\AppData\Local\Temp\ipykernel_16512\2796875381.py:1: DtypeWarning: Columns (248,249,250,251,252,253,254,255,256,257,258,259,260,261,262,263,264,265,266,267,268,269,270,271,272,273,274,275,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,291,292,293,294,295,296,297,298,299,300,301,302,303,304,305,306,307,308,309,310,311,312,313,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,338,339,340,341,342,343,344,345,346,347,348,349,350,351,352,353,354,355,356,357,358,359,360,361,362,363,364,365,366,367,368,369,370,371,372,373,374,375,376,377,378,379,380,381,382,383,384,385,386,387,388,389,390,391,392,393,394) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv('final.csv')
#       Unnamed: 0                                                0  \
# 0              0  Abacterial cystitis (Alkylating Agent Cystitis)
# 1              1        Abdominal bloating (Abdominal Distension)
# ...

# %% [markdown]
# # Tries

# %%
''' 
nan_value = type(df.iloc[0,5])
df.iloc[0,5]
# if(math.isnan(df.iloc[0,5])):
if(isinstance('omar', str)):
    print(0)
else:
    print(1)

print(type('omar'))
'''


''' 
for i in range(11):
    df_clean.at[i,0] = df.iloc[i,0]
    cell = 0
  
    
    for j in range(200):
        # if isinstance(df.iloc[i,j + 2], str):
        if type(df.iloc[i,j + 2]) == my_type:
            cell += 1
            print(j)
            df_clean.at[i,cell] = df.iloc[i,j]
            
            # if(not isinstance(df.iloc[i,j + 1],str)):
            if(type(df.iloc[i,j+3]) != my_type):
                break
'''

# %%
'''
# df_clean = pd.DataFrame()
row = df.shape[0]
col = df.shape[1]
test = pd.DataFrame()
drugs_list = []
nan_value = type(df.iloc[0,5])
print(nan_value)

# test = test.append({df.iloc[0,0]: drugs_list}, ignore_index=True)
# print(test)

for i in range(11):
    for j in range(15):
        cell = df.iloc[i + 1, j + 1]
        next_cell = df.iloc[i + 1, j + 2]
        

        if type(cell) == nan_value:
            continue
       
       
        drugs_list.append(cell)
        
            
        if type(next_cell) == nan_value:
            pd.pandas()
            test = pd.concat({df.iloc[i,0]:drugs_list}, ignore_index=True, axis=0)  
            print(test)
            break
'''


'''
# df_clean = pd.DataFrame()
row = df.shape[0]
col = df.shape[1]
test = pd.DataFrame()
drugs_list = []
nan_value = type(df.iloc[0,5])
print(nan_value)

# test = test.append({df.iloc[0,0]: drugs_list}, ignore_index=True)
# print(test)


for i in range(11):
    append_drug = False
    for j in range(15):
        cell = df.iloc[i , j]
        # next_cell = df.iloc[i + 1, j + 2] if df.iloc[i + 1, j + 2] else 0
        

        if type(cell) == nan_value or not append_drug:
            append_drug = True
            continue
       
       
        drugs_list.append(cell)
        
            
        if append_drug:
            row = pd.DataFrame({cell})
            test = test.append({df.iloc[i,0]:drugs_list}, ignore_index=True)
            print(test)
            break
'''

# %%
''' 
import pandas as pd
df = pd.read_csv('drugs.csv')
'''

''' 
#!/usr/bin/env python
my_type = type('mytype')
import csv    

myfile = './drugs.csv'
newfile = './drugs2.csv.csv'

reader = csv.reader(open(myfile))

# remove_me = {'3270','2500'}

print('Before:')
print(open(myfile).read())

for row in reader:
    new_row = []
    for column in row:
        if type(column) == my_type:
            new_row.append(column)

    csv.writer(open(newfile,'a')).writerow(new_row)

print('\n\n')
print('After:')
print(open(newfile).read())
'''
